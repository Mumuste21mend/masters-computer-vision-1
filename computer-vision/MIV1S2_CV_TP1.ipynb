# %% [markdown]
# <a href="https://colab.research.google.com/github/Mumuste21mend/masters-computer-vision-1/blob/master/computer-vision/MIV1S2_CV_TP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TP1:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###code de prog1.py :
# ```
# import numpy as np
# import cv2 as cv
# img = cv.imread('im1.jpg')
# gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)
# sift = cv.SIFT_create()
# kp = sift.detect(gray,None)
# #img=cv.drawKeypoints(gray,kp,img)
# #cv.imwrite('sift_keypoints.jpg',img)
# img=cv.drawKeypoints(gray,kp,img,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# cv.imwrite('sift_keypoints.jpg',img)
# ```

# %%
pip install opencv-python==4.5.1.48

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
img = cv.imread('/content/im1.jpg')
gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)
cv2_imshow(gray)

sift = cv.SIFT_create()
kp = sift.detect(gray,None)
img1=cv.drawKeypoints(gray,kp,img)
cv2_imshow(img1)
# cv.imwrite('sift_keypoints.jpg',img)
#cv.drawKeypoints(gray pic,key points(detected  by sift)  , real image )   
#with flags up it draws weird shapes (i don't understand what are they )
#
img2=cv.drawKeypoints(gray,kp,img,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv2_imshow(img2)

#cv.imwrite('/content/sift_keypoints.jpg',img)
# Out:
# <PIL.Image.Image image mode=L size=381x494 at 0x7F190F9A52D0>
# <PIL.Image.Image image mode=RGB size=381x494 at 0x7F1910A7EDD0>
# <PIL.Image.Image image mode=RGB size=381x494 at 0x7F190F9B1850>

# %% [markdown]
# ###code de prog2.py :
# ```
# import cv2
# import numpy as np
#
# kernel_size = 3
# scale = 1
# delta = 0
# ddepth = cv2.CV_16S #desired depth
# #variance along an axis sigmax , sigmay if sigmay=0 then it takes sigmax value
# sigma=24
#
# img = cv2.imread('im1.jpg')
# img = cv2.GaussianBlur(img,(3,3),sigma,0, cv2.BORDER_DEFAULT)
# gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#
# gray_lap = cv2.Laplacian(gray,ddepth,ksize = kernel_size,scale = scale,delta = delta)
# dst = cv2.convertScaleAbs(gray_lap)
#
# cv2.imshow('laplacian',dst)
# cv2.imwrite("LAP_imag.png", dst)
#
# cv2.waitKey(0)
# cv2.destroyAllWindows()
#
# ```

# %% [markdown]
# #TP1:
# ![image.png](data:image/png;base64,...)

# %%
import cv2
kernel_size = 3
scale = 1
delta = 0
ddepth = cv2.CV_16S
sigma=2
n=4
x=1

img = cv2.imread('/content/im1.jpg')
# cv2_imshow(img)
img = cv2.GaussianBlur(img,(3,3),sigma,0, cv2.BORDER_DEFAULT)
cv2_imshow(img)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# cv2_imshow(gray)
gray_lap = cv2.Laplacian(gray,ddepth,ksize = kernel_size,scale = scale,delta = delta)
dst = cv2.convertScaleAbs(gray_lap)
# for x in range(n):
#   gray_lap = cv2.Laplacian(dst,ddepth,ksize = kernel_size,scale = scale,delta = delta)
#   # cv2_imshow(gray_lap)
#   dst = cv2.convertScaleAbs(gray_lap)


# cv2.imshow('laplacian',dst)
# cv2.imwrite("LAP_imag.png", dst)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=381x494 at 0x7F190F9B1C90>

# %%
import cv2
kernel_size = 3
scale = 1
delta = 0
ddepth = cv2.CV_16S
sigma=24

img = cv2.imread('/content/im1.jpg')
cv2_imshow(img)
cv2_imshow(img)
img = cv2.GaussianBlur(img,(3,3),sigma,0, cv2.BORDER_DEFAULT)
cv2_imshow(img)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

gray_lap = cv2.Laplacian(gray,ddepth,ksize = kernel_size,scale = scale,delta = delta)
cv2_imshow(gray_lap)
dst = cv2.convertScaleAbs(gray_lap)
cv2_imshow(dst)

# cv2.imshow('laplacian',dst)
# cv2.imwrite("LAP_imag.png", dst)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=381x494 at 0x7F1910A88D50>
# <PIL.Image.Image image mode=RGB size=381x494 at 0x7F1910A888D0>
# <PIL.Image.Image image mode=L size=381x494 at 0x7F190F9B1E90>
# <PIL.Image.Image image mode=L size=381x494 at 0x7F191B44EC10>
# <PIL.Image.Image image mode=L size=381x494 at 0x7F190F9B13D0>
